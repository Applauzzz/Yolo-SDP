# %%
import requests
from PIL import Image, ImageDraw
from io import BytesIO
import os
import pandas as pd
from datetime import datetime
import numpy as np
import time

# %%
#converts meters to Latitude-Longitude
ImageStep = float(500/111139)
ImageSize =500
image_number = 0
# starting point


Iterations = 500
file_type = 'png'

# Enter download folder path
# path = 'C:/Users/afrob/Downloads/Mining'
path = 'D:/Downloads/Mining/'

os.chdir(path)

# %%
dir_list = os.listdir(path)


for file in dir_list:
    img  = Image.open(file)

    centre = 250

    for i in range(10,500,40): 
        print(i)
        shape = [(centre - i/2, centre - i/2), (centre + i/2, centre + i/2)] 

        img1 = ImageDraw.Draw(img)   
        img1.rectangle(shape, outline ='red', width=3) 
        img1.text((centre - i/2, centre - i/2), str(i))
    img.save("x"+file)
    # img.show()
# Out:
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# 170
# 210
# 250
# 290
# 330
# 370
# 410
# 450
# 490
# 10
# 50
# 90
# 130
# ...

# %%
img_np = np.array(img)
print(img_np.shape)
# Out:
# (500, 500, 3)
